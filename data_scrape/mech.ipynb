# %%
import mechanize
from bs4 import BeautifulSoup
import selenium 
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

# %%
#https://github.com/jocobtt/Python-projects/blob/master/py_scrape.py

# %%
driver = webdriver.Chrome("/Users/jabras/Downloads/chromedriver")

# %%
url = "https://www.navitime.co.jp/maps/routeSearch"

# %%
start_ex = "東京都中野区新井１丁目２５−4"

# %%
goal_official = "六本木ヒルズ"

# %%
# try out finding the keys i want in selenium
if __name__ == '__main__':
    driver.get(url)

# %%
# remove cars as option - still not able to get there 
#car_part = driver.find_elements_by_xpath('//*[@id="route-search-detail-link__default"]/a').
# Out:
#   File "<ipython-input-7-7e36b8299c63>", line 2
#     car_part = driver.find_elements_by_xpath('//*[@id="route-search-detail-link__default"]/a').
#                                                                                                ^
# SyntaxError: invalid syntax

# %%
# input address and click on start location search button 
location_search = driver.find_element_by_class_name('start-input').send_keys(start_ex)  # instead of start_ex just have it use loop addresses

# click on search button 
start_button = driver.find_element_by_class_name('//*[@id="route-search-start-box"]/div[1]/button').click() # fix this
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-8-1ac0e766f9c5> in <module>
#       3
#       4 # click on search button
# ----> 5 start_button = driver.find_element_by_class_name('//*[@id="route-search-start-box"]/div[1]/button').click() # fix this
#       6
#       7 # need logic statement for first option that pops up...
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSelectorException: Message: invalid selector: An invalid or illegal selector was specified
#   (Session info: chrome=87.0.4280.67)

# %%
# need logic statement for first option that pops up... 
click_start_op = driver.find_element_by_xpath('//*[@id="route-search-start-box"]/div[2]/section/ul[1]/li[1]/a').click()

# %%
# input address and click on goal location search button 
goal_search = driver.find_element_by_class_name('goal-input').send_keys(goal_official)

# click on search button for goal 
goal_button = driver.find_element_by_xpath('//*[@id="route-search-goal-box"]/div[1]/button')

# %%
# again needs logic to click on top option 
click_goal_op = driver.find_element_by_xpath('//*[@id="route-search-goal-box"]/div[2]/section/ul[1]/li[1]/a').click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-10-0f3f0c8197da> in <module>
#       1 # again needs logic to click on top option
# ----> 2 click_first_op = driver.find_element_by_class_name('kw-result-item').click()
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=87.0.4280.67)

# %%
# click on main search button 
search = driver.find_element_by_xpath('//*[@id="route-search-condition-content"]/div/div[7]/button') # this doesn't totally work yet...

# %%
# get url that we are currently on to pull down long and lat - see if we can't format url from this 
current_url = driver.current_url

# %%
# get second route so that we don't have the car option 
second = driver.find_element_by_xpath('//*[@id="ui-id-3"]').click()

# %%
# pull down price 
price = driver.find_element_by_xpath('//*[@id="route-2"]/div[1]/div[3]/div[2]/div[2]/div/div').text
print(price)
# Out:
# 380円 (IC:377円)

# %%
# get time elapsed 
time = driver.find_element_by_xpath('//*[@id="route-2"]/div[1]/div[1]/span[1]').text
print(time)
# Out:
# 46分

# %%
# number of train changes 
changes = driver.find_element_by_xpath('//*[@id="route-2"]/div[1]/div[3]/div[1]/div[2]/div/div').text
print(changes)
# Out:
# 1回

# %%
# get bike route only ...
click_bike = driver.find_element_by_xpath('//*[@id="route-search-types"]/label[4]/div').click()
# wait a few seconds 
# sleep('1m')
bike_time = driver.find_element_by_xpath('//*[@id="route-1"]/div[1]/div[1]/span[1]').text
bike_dist = driver.find_element_by_xpath('//*[@id="route-1"]/div[1]/div[2]/div[1]/div[2]/div/div').text
calories = driver.find_element_by_xpath('//*[@id="route-1"]/div[1]/div[2]/div[2]/div[2]/div/div').text
print(bike_time)
print(bike_dist)
print(calories)
# Out:
# 48分
# 9.3km
# 262.9kcal

# %%
br = mechanize.Browser()

# %%
r = br.open(url)

# %%
# add user agent 
br.addheaders = [('User-agent', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1')]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1f208099dbd0> in <module>
# ----> 1 html = r.read()
#
# NameError: name 'r' is not defined

# %%
# get the url - use this to pull off url so that we can get lon and lat 
r.geturl()
# Out:
# 'https://www.navitime.co.jp/maps/routeSearch'

# %%
# run this through beautifulsoup 
#html = r.read()

# %%
html
# Out:
# b'<!doctype html>\n<html lang="ja">\n<head>\n  <meta charset="utf-8" />\n  <title>\xe5\x9c\xb0\xe5\x9b\xb3\xe6\xa4\x9c\xe7\xb4\xa2 - NAVITIME</title>\n  <meta name="description" content="NAVITIME"/>\n  <script>\n\twindow.grumi = {       \n\t\tkey: \'7bf94851-9056-43da-bba6-089a92e49ec3\'\n\t\t};\n</script>\n<script src="//rumcdn.geoedge.be/7bf94851-9056-43da-bba6-089a92e49ec3/grumi-ip.js" async></script>\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/map/map.css">\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/lib/jquery.loading/jquery.loading.css">\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.structure.min.css">\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.theme.min.css">\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.structure.custom.css">\n<link rel="stylesheet" href="/static/pc/l/11.5.3/css/common/loginPopup.css">\n<link rel="dns-prefetch" href="//www.navitime.co.jp"/>\n  <link rel="dns-prefetch" href="//www.google-analytics.com"/>\n  <link rel="dns-prefetch" href="//www.facebook.com"/>\n  <link rel="dns-prefetch" href="//spnet2-1.i-mobile.co.jp"/>\n  <link rel="canonical" href="https://www.navitime.co.jp/maps/">\n  <link rel="alternate" media="only screen and (max-width: 640px)" href="https://touch.navitime.co.jp/map/top/">\n  <link rel="shortcut icon" href="/static/pc/l/11.5.3/img/common/favicon.ico" type="image/vnd.microsoft.icon">\n  <link rel="icon" href="/static/pc/l/11.5.3/img/common/favicon.ico" type="image/vnd.microsoft.icon">\n  </head>\n<body>\n  <script src="//cdn.ravenjs.com/3.9.2/raven.min.js"></script>\n\t\t\t<script>Raven.config(\'https://e449deb2e6b14ec7903e2f7e48514120@sentry.navitime.co.jp/11\').install();</script>\n\t\t\t\t<script>\n\t\twindow.onerror = function(message, file, line, col, error) {\n\t\t\tRaven.captureException(error);\n\t\t}\n\t</script>\n<script src="//mapscript.cld.navitime.jp/v1/00010001/mapscript?version=3.14"></script>\n\t<script src="//mapscript.cld.navitime.jp/gaia/1.0.1/index.js"></script><script src="//mapscript.cld.navitime.jp/ozone/index.js"></script>\n\t<script>OZONE.config.tilescript = function() {return true;};</script>\n<div id="map-header">\n\t\t<div class="top-area">\n\t<div class="left-area float-left">\n\t\t<div class="flex-area">\n\t\t\t<a href="//www.navitime.co.jp" class="logo" style="float: left; width: 97px;" data-ga-click=\'{"action":"\xe3\x83\x98\xe3\x83\x83\xe3\x83\x80\xe3\x83\xbc", "label":"TOP\xe3\x83\xaa\xe3\x83\xb3\xe3\x82\xaf"}\'><img src="/static/pc/l/11.5.3/img/common/header/logo/logo_header_ntj.svg" style="width: 97px;"></a>\n\t\t\t<div class="asp-link">\n<a id="asp_link_a" class="inline-block" on ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <meta charset="utf-8"/>
# <title>地図検索 - NAVITIME</title>
# <meta content="NAVITIMEで地図を検索。電車やバスの乗換案内や車ルート検索、施設名・地名・住所などから地図の検索や周辺スポットの検索が可能です。航空写真や混雑情報、降雨レーダなどの地図も確認できます。お気に入りの場所を登録・保存できます。" name="description"/>
# <script>
# 	window.grumi = {
# 		key: '7bf94851-9056-43da-bba6-089a92e49ec3'
# 		};
# </script>
# <script async="" src="//rumcdn.geoedge.be/7bf94851-9056-43da-bba6-089a92e49ec3/grumi-ip.js"></script>
# <link href="/static/pc/l/11.5.3/css/map/map.css" rel="stylesheet"/>
# <link href="/static/pc/l/11.5.3/css/lib/jquery.loading/jquery.loading.css" rel="stylesheet"/>
# <link href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.structure.min.css" rel="stylesheet"/>
# <link href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.theme.min.css" rel="stylesheet"/>
# <link href="/static/pc/l/11.5.3/css/lib/jquery-ui/jquery-ui.structure.custom.css" rel="stylesheet"/>
# <link href="/static/pc/l/11.5.3/css/common/loginPopup.css" rel="stylesheet"/>
# <link href="//www.navitime.co.jp" rel="dns-prefetch">
# <link href="//www.google-analytics.com" rel="dns-prefetch">
# <link href="//www.facebook.com" rel="dns-prefetch">
# <link href="//spnet2-1.i-mobile.co.jp" rel="dns-prefetch">
# <link href="https://www.navitime.co.jp/maps/" rel="canonical"/>
# <link href="https://touch.navitime.co.jp/map/top/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/static/pc/l/11.5.3/img/common/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/static/pc/l/11.5.3/img/common/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# </link></link></link></link></head>
# <body>
# <script src="//cdn.ravenjs.com/3.9.2/raven.min.js"></script>
# <script>Raven.config('https://e449deb2e6b14ec7903e2f7e48514120@sentry.navitime.co.jp/11').install();</script>
# <script>
# 		window.onerror = function(message, file, line, col, error) {
# 			Raven.captureException(error);
# 		}
# 	</script>
# <script src="//mapscript.cld.navitime.jp/v1/00010001/mapscript?version=3.14"></script>
# <script src="//mapscript.cld.navitime.jp/gaia/1.0.1/index.js"></script><script src="//mapscript.cld.navitime.jp/ozone/index.js"></script>
# <script>OZONE.config.tilescript = function() {return true;};</script>
# <div id="map-header">
# <div class="top-area">
# <div class="left-area float-left">
# <div class="flex-area">
# <a class="logo" data-ga-click='{"action":"ヘッダー", "label":"TOPリンク"}' href="//www.navitime.co.jp" style="float: left; width: 97px;"><img src="/static/pc/l/11.5.3/img/common/header/logo/logo_header_ntj.svg" style="width: 97px;"/></a>
# <div class="asp-link">
# <a class="inline-block" id="asp_link_a" onclick="window.open('https://www.navitime.co.jp/location-platform/products/media.html?from=pc_map&amp;ver=a');return false;" style="color: #006400; display: none;">MEO・SEO対策にお困りの方へ</a>
# <a class="inline-block" id="asp_link_b" onclick="window.open('https://www.navitime.co.jp/location-platform/products/media.html?from=pc_map&amp;ver=b');return false;" style="color: #006400; display: none;">NAVITIMEの経路探索や地図機能を自社導入しませんか</a>
# <a class="inline-block" id="asp_link_c" onclick="window.open('https://www.navitime.co.jp/advertising/?from=pc_map');return false;" style="color: #006400; display: none;">NAVITIMEに広告掲載をしてみませんか？</a>
# <a class="inline-block" id="asp_link_d" onclick="window.open('https://www.navitime.co.jp/navitime-business-account/?from=pc_map');return false;" style="color: #006400; display: none;">新たな福利厚生のご提案「移動の“ 密 ”回避」</a>｜
# <a class="opinipn-map" data-ga-click='{"action":"ヘッダー上", "label":"ご意見/ご要望"}' style="font-size: 12px; color: #006400" target="_blank"> ご意見</a>
# </div>
# </div>
# <div class="function-area float-left">
# <div class="search-container float-left" id="global-search-box">
# <input placeholder="港区赤坂、駐車場" type="search"/>
# <div class="search-box__btn-container">
# <button class="search-box__search-btn" id="global-search-btn"></button>
# </div>
# <div id="global-drop-down">
# <div id="kw-single-data-area"></div>
# <div id="kw-multi-data-area"></div>
# </div>
# </div>
# <div class="flex-area">
# <button class="function-btn green-btn float-left route-search" data-ga-click='{"action":"ヘッダー", "label":"ルート検索"}'>
# <div>ルート検索</div>
# </button>
# <button class="function-btn green-btn float-left around-search" data-ga-click='{"action":"ヘッダー", "label":"周辺検索"}'>
# <div>周辺検索</div>
# </button>
# <button class="function-btn tool-btn float-left map-tool" data-ga-click='{"action":"ヘッダー", "label":"地図の種類"}'>
# <div>地図の種類</div>
# </button>
# <button class="function-btn tool-btn tool-btn--sansan float-left cooperation-login" data-ga-click='{"action":"ヘッダー", "label":"sansan連携"}'>
# <div class="cooperation__new-mark">\ new /</div>
# <div>Sansan連携</div>
# </button>
# </div>
# </div>
# </div>
# <div class="criteo float-right" id="area-target-banner"></div>
# <ul class="float-right" id="new-area-target-banner"></ul>
# </div>
# <div class="bottom-area">
# <a class="global-btn" data-ga-click='{"action":"ヘッダー", "label":"地図の中心から再検索"}' id="search-this-area" style="display: none">
# <span>地図の中心から再検索</span>
# </a>
# <div class="bottom-contents">
# <div class="" id="header-map-function">
# <div class="map-action-btn map-action-list-btn" data-ga-click='{"action":"ヘッダー", "label":"地図操作ボタン"}'>写真・渋滞情報<img class="nextarrow-green-under" src="/static/pc/l/11.5.3/img/map/common/nextarrow-green-under.svg"/></div>
# <ul class="map-action-list">
# <li class="location" data-ga-click='{"action":"ヘッダー", "label":"現在地"}'>
# <div class="float-left text">現在地</div>
# <div class="float-right img-icon_check"></div>
# </li>
# <li class="satellite" data-ga-click='{"action":"ヘッダー", "label":"航空・衛星写真"}'>
# <div class="float-left text">航空・衛星写真</div>
# <div class="float-right img-icon_check"></div>
# </li>
# <li data-ga-click='{"action":"ヘッダー", "label":"渋滞情報(無料)"}' id="modal-open">
# <a class="float-left text">渋滞情報</a>
# <div class="float-left img-icon_key"></div>
# <div class="float-right img-icon_check"></div>
# </li>
# <li class="rainfall" data-ga-click='{"action":"ヘッダー", "label":"降雨レーダー"}'>
# <div class="float-left text">降雨レーダー</div>
# <div class="float-right img-icon_check"></div>
# </li>
# </ul>
# </div>
# <div class="" id="header-user-function">
# <div class="map-action-btn map-action-list-btn" data-ga-click='{"action":"ヘッダー", "label":"ユーザ情報ボタン"}'>ログイン<img class="nextarrow-green-under" src="/static/pc/l/11.5.3/img/map/common/nextarrow-green-under.svg"/></div>
# <ul class="map-action-list">
# <li class="login" data-ga-click='{"action":"ヘッダー", "label":"ログイン"}' id="modal-open"><div class="text">ログイン</div></li>
# <li class="regist" data-ga-click='{"action":"ヘッダー", "label":"新規会員登録"}'><a class="text" href="https://pcc.navitime.co.jp/navitimeid/pcc/mobilelist/?invite=lmap_user_list">新規会員登録</a></li>
# <li data-ga-click='{"action":"ヘッダー", "label":"履歴/My地点"}' id="modal-open">
# <a class="float-left text">履歴/My地点</a>
# <div class="float-left img-icon_key"></div>
# </li>
# <hr/>
# <li class="opinion" data-ga-click='{"action":"ヘッダー", "label":"ご意見/ご要望"}'><div class="text">ご意見/ご要望</div></li>
# </ul>
# </div>
# <div class="">
# <div class="map-action-btn" data-ga-click='{"action":"ヘッダー", "label":"地図印刷"}' id="header-map-print"><img src="/static/pc/l/11.5.3/img/map/common/print-green.svg" style="width: 20px; margin-right: 2px;"/>地図印刷</div>
# </div>
# <div class="">
# <div class="map-action-btn" data-ga-click='{"action":"ヘッダー", "label":"メール送信"}' id="header-map-mail"><img src="/static/pc/l/11.5.3/img/map/common/mail-gray.svg" style="margin-right: 2px;"/>メール送信</div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	document.addEventListener('DOMContentLoaded', function(){
# 		//ASPリンクの文言をA/Bテストする 2019.12.17
# 		var rand = Math.floor( Math.random() * 4);
# 		if(rand == 1) {
# 			$('#asp_link_a').show();
# 			$('#asp_link_b').hide();
# 			$('#asp_link_c').hide();
# 			$('#asp_link_d').hide();
# 		} else if(rand == 2) {
# 			$('#asp_link_b').show();
# 			$('#asp_link_a').hide();
# 			$('#asp_link_c').hide();
# 			$('#asp_link_d').hide();
# 		} else if(rand == 3) {
# 			$('#asp_link_c').show();
# 			$('#asp_link_b').hide();
# 			$('#asp_link_a').hide();
# 			$('#asp_link_d').hide();
# 		} else {
# 			$('#asp_link_d').show();
# 			$('#asp_link_a').hide();
# 			$('#asp_link_b').hide();
# 			$('#asp_link_c').hide();
# 		}
# 	}, false);
#
# 	// 吹き出しフェードアウト
# 	setTimeout(function() {
# 		$('.balloon-area').fadeOut('300');
# 	}, 30000);
# </script>
# </div>
# <div id="map"></div>
# <div id="map-left-pane">
# <div id="left-pane">
# <a class="tab route-search img-left_tab_close" data-ga-click='{"action":"左パネル", "label":"ルート検索"}'></a>
# <div class="pane-content">
# <div id="route-info">
# <div id="route-search-header">
# <div class="title-area">
# <div class="float-left img-icon_title_total"></div>
# <div class="float-left text">ルート検索</div>
# </div>
# <div id="route-search-types">
# <label class="tab-total selected">
# <input checked="" name="route-type" type="radio" value="total"/>
# <div class="img-icon_tab_total_pressed" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビタブ"}'></div>
# </label>
# <label class="tab-car">
# <input name="route-type" type="radio" value="car"/>
# <div class="img-icon_tab_car_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"車タブ"}'></div>
# </label>
# <label class="tab-walk">
# <input name="route-type" type="radio" value="walk"/>
# <div class="img-icon_tab_walk_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩タブ"}'></div>
# </label>
# <label class="tab-bicycle">
# <input name="route-type" type="radio" value="bicycle"/>
# <div class="img-icon_tab_bicycle_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"自転車タブ"}'></div>
# </label>
# <label class="tab-truck">
# <input name="route-type" type="radio" value="truck"/>
# <div class="img-icon_tab_truck_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"トラックタブ"}'></div>
# </label>
# </div>
# </div>
# <div id="route-search-content">
# <div id="route-search-condition-content">
# <div class="wrapper">
# <div class="search-box-content" data-box="start" id="route-search-start-box">
# <div class="search-box route-search-box">
# <label class="start">出発</label>
# <input class="start-input" placeholder="出発地を入力" type="text">
# <input type="hidden" value=""/>
# <button class="search-btn orange-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"地点検索ボタン"}'>
# <div class="img-icon_btn_search"></div>
# </button>
# </input></div>
# <div class="search-result"></div>
# <div class="suggest-result"></div>
# </div>
# <div id="search-box-container">
# <div class="img-btn_replace_normal sg-change-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"SG入れ替えボタン"}'></div>
# <div class="route-search-via-box-container"></div>
# </div>
# <div id="route-search-via">
# <div class="add-via-btn img-btn_bg_via_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"経由地を追加"}' data-via-max="8">経由地を追加</div>
# </div>
# <div id="attention-text" style="font-size: 12px; text-align: center; color: #c3001e"></div>
# <div class="search-box-content" data-box="goal" id="route-search-goal-box">
# <div class="search-box route-search-box">
# <label class="goal">目的</label>
# <input class="goal-input" placeholder="目的地を入力" type="text">
# <input type="hidden" value=""/>
# <button class="search-btn orange-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"地点検索ボタン"}'>
# <div class="img-icon_btn_search"></div>
# </button>
# </input></div>
# <div class="search-result"></div>
# <div class="suggest-result"></div>
# </div>
# <div id="route-search-conditions">
# <div class="route-search-dates">
# <span class="route-search-conditions-title">日付</span>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"年月"}' name="yearmonth"></select>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"日"}' name="date">
# <option value="1">1日</option>
# <option value="2">2日</option>
# <option value="3">3日</option>
# <option value="4">4日</option>
# <option value="5">5日</option>
# <option value="6">6日</option>
# <option value="7">7日</option>
# <option value="8">8日</option>
# <option value="9">9日</option>
# <option value="10">10日</option>
# <option value="11">11日</option>
# <option value="12">12日</option>
# <option value="13">13日</option>
# <option value="14">14日</option>
# <option value="15">15日</option>
# <option value="16">16日</option>
# <option value="17">17日</option>
# <option value="18">18日</option>
# <option value="19">19日</option>
# <option value="20">20日</option>
# <option value="21">21日</option>
# <option value="22">22日</option>
# <option value="23">23日</option>
# <option value="24">24日</option>
# <option value="25">25日</option>
# <option value="26">26日</option>
# <option value="27">27日</option>
# <option value="28">28日</option>
# <option value="29">29日</option>
# <option value="30">30日</option>
# <option value="31">31日</option>
# </select>
# <div class="img-icon_calender"></div>
# <a class="calendar-link" data-ga-click='{"action":"ルート検索_TOP", "label":"カレンダー"}'>カレンダー</a>
# <input id="route-search-calendar" type="text"/>
# </div>
# <div class="route-search-times">
# <span class="route-search-conditions-title">時刻</span>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"時"}' name="hour">
# <option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# <option value="13">13</option>
# <option value="14">14</option>
# <option value="15">15</option>
# <option value="16">16</option>
# <option value="17">17</option>
# <option value="18">18</option>
# <option value="19">19</option>
# <option value="20">20</option>
# <option value="21">21</option>
# <option value="22">22</option>
# <option value="23">23</option>
# </select>
# <span>時</span>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"分"}' name="minute">
# <option value="0">0</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# <option value="13">13</option>
# <option value="14">14</option>
# <option value="15">15</option>
# <option value="16">16</option>
# <option value="17">17</option>
# <option value="18">18</option>
# <option value="19">19</option>
# <option value="20">20</option>
# <option value="21">21</option>
# <option value="22">22</option>
# <option value="23">23</option>
# <option value="24">24</option>
# <option value="25">25</option>
# <option value="26">26</option>
# <option value="27">27</option>
# <option value="28">28</option>
# <option value="29">29</option>
# <option value="30">30</option>
# <option value="31">31</option>
# <option value="32">32</option>
# <option value="33">33</option>
# <option value="34">34</option>
# <option value="35">35</option>
# <option value="36">36</option>
# <option value="37">37</option>
# <option value="38">38</option>
# <option value="39">39</option>
# <option value="40">40</option>
# <option value="41">41</option>
# <option value="42">42</option>
# <option value="43">43</option>
# <option value="44">44</option>
# <option value="45">45</option>
# <option value="46">46</option>
# <option value="47">47</option>
# <option value="48">48</option>
# <option value="49">49</option>
# <option value="50">50</option>
# <option value="51">51</option>
# <option value="52">52</option>
# <option value="53">53</option>
# <option value="54">54</option>
# <option value="55">55</option>
# <option value="56">56</option>
# <option value="57">57</option>
# <option value="58">58</option>
# <option value="59">59</option>
# </select>
# <span>分</span>
# <button class="currentTime-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"現在時刻"}'>現在時刻</button>
# </div>
# <div class="route-search-deparv">
# <input checked="" id="start-time" name="deparv" type="radio" value="start-time"/>
# <label class="checked" data-ga-click='{"action":"ルート検索_TOP", "label":"出発"}' for="start-time">出発</label>
# <input id="goal-time" name="deparv" type="radio" value="goal-time"/>
# <label class="" data-ga-click='{"action":"ルート検索_TOP", "label":"到着"}' for="goal-time">到着</label>
# <input id="first-operation" name="deparv" type="radio" value="first-operation"/>
# <label class="" data-ga-click='{"action":"ルート検索_TOP", "label":"始発"}' for="first-operation">始発</label>
# <input id="last-operation" name="deparv" type="radio" value="last-operation"/>
# <label class="" data-ga-click='{"action":"ルート検索_TOP", "label":"終電"}' for="last-operation">終電</label>
# </div>
# <div id="truck-route-search-type-box">
# <label class="truck-condition__title" for="">サンプル値から条件を設定 (<a class="truck-condition__modal-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル詳細"}' id="truck-preset-modal">詳細</a>)</label>
# <div class="truck-modal" id="truck-preset-modal-main">
# <div class="truck-modal__bg js-truck-preset-modal-close"></div>
# <div class="truck-modal__content">
# <h2>車種について</h2>
# <p>各項目を選択していただくことで、詳細条件にサンプルの値を自動で入力します。</p>
# <p>入力される値としましては、以下のとおりです。</p>
# <table class="truck-modal__table">
# <thead>
# <tr class="truck-modal__table--header">
# <th></th>
# <th>軽貨物車</th>
# <th>中型車</th>
# <th>大型車</th>
# <th>特大車</th>
# </tr>
# </thead>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">料金区分</th>
# <th>普通車料金</th>
# <th>中型車料金</th>
# <th>大型車料金</th>
# <th>特大車料金</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">車種区分</th>
# <th>普通貨物自動車</th>
# <th>準中型貨物自動車</th>
# <th>大型貨物自動車</th>
# <th>大型貨物自動車</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">車長</th>
# <th>〜5000mm</th>
# <th>〜7000mm</th>
# <th>〜8000mm</th>
# <th>〜21000mm</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">車高</th>
# <th>〜2000mm</th>
# <th>〜3500mm</th>
# <th>〜3800mm</th>
# <th>〜4100mm</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">車幅</th>
# <th>〜1700mm</th>
# <th>〜2500mm</th>
# <th>〜2500mm</th>
# <th>〜2500mm</th>
# </tr>
# </table>
# <a class="js-truck-preset-modal-close" data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル詳細閉じる"}'>閉じる</a>
# </div>
# </div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル値入力"}' id="truck-type-select" name="regulation-type">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル軽貨物車"}' value="light-truck">軽貨物車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル中型車"}' value="medium-truck">中型車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル大型車"}' selected="" value="large-truck">大型車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル特大車"}' value="oversized-truck">特大車</option>
# </select>
# </div>
# <div>
# <div class="route-search-details-link" id="route-search-detail-link__default">
# <a data-ga-click='{"action":"ルート検索_TOP", "label":"詳細条件設定"}'>詳細条件設定 +</a>
# </div>
# <div class="route-search-details-link route-search-details-link__truck" id="route-search-detail-link__truck">
# <a data-ga-click='{"action":"ルート検索_TOP", "label":"トラック詳細条件設定"}'>詳細条件設定 +</a>
# </div>
# <div class="route-search-details">
# <section id="route-search-total-cond">
# <section class="free-pass-cond">
# <div class="title">フリーパス<span class="new-tag">NEW</span></div>
# <select id="free-pass-select" name="free-pass">
# <option selected="" value="0">指定なし</option>
# <option value="1">青春18きっぷ</option>
# <option value="2">大阪周遊パス1日券(大阪エリア版)</option>
# <option value="3">大阪周遊パス1日券（阪急拡大版)</option>
# <option value="4">大阪周遊パス1日券(阪神拡大版)</option>
# <option value="5">大阪周遊パス1日券(南海関空版)</option>
# <option value="6">大阪周遊パス1日券(万博記念公園版)</option>
# <option value="7">大阪周遊パス2日券</option>
# <option value="8">ようこそ大阪きっぷ（乗り降り自由区間のみ対応）</option>
# <option value="9">高野山・世界遺産きっぷ（乗り降り自由区間のみ対応）</option>
# <option value="10">江の島・鎌倉フリーパス（乗り降り自由区間のみ対応）</option>
# <option value="11">箱根フリーパス（乗り降り自由区間のみ対応）</option>
# <option value="12">カンサイスルーパス 2dayチケット</option>
# <option value="13">東京メトロ24時間券</option>
# <option value="14">東京フリーきっぷ</option>
# </select>
# </section>
# <section class="move-cond">
# <div class="title">移動手段</div>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_タクシー優先"}' disabled="" id="with_car" name="move" type="checkbox"/>
# <label for="with_car">タクシー優先<span class="inline-block img-icon_key"></span></label>
# <br/>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_自動車"}' id="only.mix" name="car" type="checkbox" value="only.mix"/>
# <label for="only.mix">自動車</label>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_渋滞考慮"}' disabled="" id="traffic" name="use-traffic" type="checkbox"/>
# <label for="traffic">渋滞考慮<span class="inline-block img-icon_key"></span></label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_有料道路"}' id="toll" name="road-fare" type="checkbox" value="toll"/>
# <label for="toll">有料道路</label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_スマートIC"}' id="smic" name="car-route" type="checkbox" value="smic"/>
# <label for="smic">スマートIC考慮(<a onclick="window.open('//www.navitime.co.jp/pcstorage/html/smicinfo.html','','width=360,height=300');return false;">詳細</a>)</label>
# </section>
# <section class="order-cond">
# <div class="title">ルート表示順</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_ルート表示順"}' id="order-select" name="order">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_時間短い順"}' selected="" value="time">時間短い順</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_運賃安い順"}' value="fare">運賃安い順</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_乗換少ない順"}' value="transit">乗換少ない順</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_歩き少ない順"}' value="walk_distance">歩き少ない順</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_CO2少ない順"}' value="co2">CO2少ない順</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_エレベーター優先"}' value="elevator">エレベーター優先</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_エレベーター・エスカレーター優先"}' value="escalator">エレベーター・エスカレーター優先</option>
# </select>
# <div>
# <a data-ga-click='{"action":"ルート検索_TOP", "label":"定期券区間を登録"}' href="//www.navitime.co.jp/account/my/commuter/search">定期券区間を登録</a>
# <div>定期券区間優先ルート検索で交通費を節約!</div>
# </div>
# </section>
# <section class="use-cond">
# <div class="gradient-area" style="display: none;"></div>
# <div class="title">使用路線</div>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_飛行機"}' id="domestic_flight" name="unuse" type="checkbox" value="domestic_flight"/>
# <label for="domestic_flight">飛行機</label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_新幹線"}' id="superexpress_train" name="unuse" type="checkbox" value="superexpress_train"/>
# <label for="superexpress_train">新幹線</label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_特急線"}' id="ultraexpress_train" name="unuse" type="checkbox" value="ultraexpress_train.sleeper_ultraexpress"/>
# <label for="ultraexpress_train">特急線</label>
# <br/>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_路線バス"}' id="local_bus" name="unuse" type="checkbox" value="local_bus"/>
# <label for="local_bus">路線バス(<a onclick="window.open('//www.navitime.co.jp/serviceinfo/buscompanylist/','','width=360,height=460,resizable=yes,scrollbars=yes');return false;">対応路線</a>)</label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_高速バス"}' id="highway_bus" name="unuse" type="checkbox" value="highway_bus"/>
# <label for="highway_bus">高速バス</label>
# <br/>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_フェリー"}' id="ferry" name="unuse" type="checkbox" value="ferry"/>
# <label for="ferry">フェリー</label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_その他有料路線"}' id="other_transport" name="unuse" type="checkbox" value="express_train.semiexpress_train"/>
# <label for="other_transport">その他有料路線</label>
# </section>
# <section class="walkSpeed-cond">
# <div class="title">徒歩速度</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_徒歩速度"}' name="walk-speed">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_ゆっくり"}' value="slow">ゆっくり(時速4km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_標準"}' selected="" value="standard">標準(時速5km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_せかせか"}' value="fast">せかせか(時速6km)</option>
# </select>
# </section>
# <section class="walkRoute-cond">
# <div class="title">優先ルート</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_優先ルート"}' name="walk-route">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_距離が短い"}' selected="" value="distance">距離が短い</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_屋根が多い"}' value="avoid_rain">屋根が多い</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トータルナビ条件_階段が少ない"}' value="avoid_step">階段が少ない</option>
# </select>
# </section>
# </section>
# <section id="route-search-car-cond">
# <section class="move-cond">
# <div class="title">移動手段</div>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"車条件_渋滞考慮"}' disabled="" id="car-traffic" name="use-traffic" type="checkbox"/>
# <label for="car-traffic" id="modal-open">渋滞考慮<span class="inline-block img-icon_key"></span></label>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"車条件_スマートIC"}' id="car-smic" name="car-route" type="checkbox" value="smic"/>
# <label for="car-smic">スマートIC考慮(<a onclick="window.open('//www.navitime.co.jp/pcstorage/html/smicinfo.html','','width=360,height=300');return false;">詳細</a>)</label>
# </section>
# </section>
# <section id="route-search-walk-cond">
# <section class="walkSpeed-cond">
# <div class="title">徒歩速度</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_徒歩速度"}' name="walk-speed">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_ゆっくり"}' value="slow">ゆっくり(時速4km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_標準"}' selected="" value="standard">標準(時速5km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_せかせか"}' value="fast">せかせか(時速6km)</option>
# </select>
# </section>
# <section class="walkRoute-cond">
# <div class="title">優先ルート</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_優先ルート"}' name="walk-route">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_距離が短い"}' selected="" value="distance">距離が短い</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_屋根が多い"}' value="avoid_rain">屋根が多い</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"徒歩条件_階段が少ない"}' value="avoid_step">階段が少ない</option>
# </select>
# </section>
# </section>
# <section id="route-search-bicycle-cond">
# <section class="bicycleSpeed-cond">
# <div class="title">自転車速度</div>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"自転車条件_自転車速度"}' name="bicycle-speed">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"自転車条件_ゆっくり"}' value="7">ゆっくり(時速7km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"自転車条件_標準"}' selected="" value="13">標準(時速13km)</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"自転車条件_遅め"}' value="20">速め(時速20km)</option>
# </select>
# </section>
# </section>
# <section id="route-search-truck-cond">
# <section class="move-cond truck-condition">
# <div class="title">検索条件</div>
# <div>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_渋滞考慮"}' disabled="" id="use-traffic" name="use-traffic" type="checkbox"/>
# <label class="modal-open" for="use-traffic">渋滞考慮<span class="inline-block img-icon_key"></span></label>
# </div>
# <div>
# <input checked="" data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_スマートIC"}' id="truck-smic" name="truck-smic" type="checkbox" value="smic"/>
# <label for="truck-smic">スマートIC考慮(<a onclick="window.open('//www.navitime.co.jp/pcstorage/html/smicinfo.html','','width=360,height=300');return false;">詳細</a>)</label>
# </div>
# <div>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_フェリー利用"}' id="truck-ferry" name="truck-ferry" type="checkbox" value="ferry_more"/>
# <label for="truck-ferry">フェリー利用</label>
# </div>
# <div>
# <input data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_ゾーン30回避"}' disabled="" id="truck-zone30" name="truck-zone30" type="checkbox"/>
# <label class="modal-open" for="truck-zone30">ゾーン30回避<span class="inline-block img-icon_key"></span></label>
# </div>
# <label class="truck-condition__title" for="">料金区分</label>
# <select data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_料金区分"}' id="truck-fare" name="toll-type">
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_普通車料金"}' value="2">普通車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_中型車料金"}' value="3">中型車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_大型車料金"}' selected="" value="4">大型車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_特大車料金"}' value="5">特大車</option>
# </select>
# <label class="truck-condition__title" for="">
# 		車種区分 (<a class="truck-condition__modal-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車種区分詳細"}' id="truck-type-modal">詳細</a>)
# 		<span class="inline-block img-icon_key"></span></label>
# <div class="truck-modal" data-ga-click='{"action":"ルート検索_TOP", "label":"トラック検索_サンプル値入力"}' id="truck-modal-main">
# <div class="truck-modal__bg js-truck-modal-close"></div>
# <div class="truck-modal__content">
# <h2>車種区分とは</h2>
# <p>道路交通法で定められている車両種別のことです。車両総重量、最大積載量によって区別されます。</p>
# <p>以下の通り、分類されます。</p>
# <table class="truck-modal__table">
# <thead>
# <tr class="truck-modal__table--header">
# <th>車種区分</th>
# <th>車両総重量</th>
# <th>最大積載量</th>
# </tr>
# </thead>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">普通貨物自動車</th>
# <th>〜3.5t</th>
# <th>〜2t</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">準中型貨物自動車</th>
# <th>3.5t〜7.5t</th>
# <th>2t〜4.5t</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">特定中型以外の中型貨物自動車</th>
# <th>7.5t〜8t</th>
# <th>4.5〜5t</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">特定中型貨物自動車</th>
# <th>8t〜11t</th>
# <th>5t〜6.5t</th>
# </tr>
# <tr class="truck-modal__table--contents">
# <th class="truck-modal__table--title">大型貨物自動車</th>
# <th>11t〜20t</th>
# <th>6.5t〜20t</th>
# </tr>
# </table>
# <a class="js-truck-modal-close">閉じる</a>
# </div>
# </div>
# <div class="truck-condition__fit-content modal-open">
# <div class="truck-condition__fit-content--disabled">
# <select disabled="" id="truck-type-dummy" name="truck-type"> <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_普通貨物自動車"}' value="5">普通貨物自動車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_準中型貨物自動車"}' value="14">準中型貨物自動車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_特定中型以外の中型貨物自動車"}' value="6">特定中型以外の中型貨物自動車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_特定中型貨物自動車"}' selected="" value="7">特定中型貨物自動車</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_大型貨物自動車"}' value="8">大型貨物自動車</option>
# </select>
# </div>
# </div>
# <label class="truck-condition__title" for="">車長<span class="inline-block img-icon_key"></span></label>
# <div class="truck-condition__fit-content modal-open">
# <div class="truck-condition__fit-content--disabled">
# <select disabled="" id="truck-length-dummy" name="car-length">
# <option value="-1">指定なし</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長2000"}' value="200">〜2000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長3000"}' value="300">〜3000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長4000"}' value="400">〜4000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長5000"}' value="500">〜5000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長6000"}' value="600">〜6000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長7000"}' value="700">〜7000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長8000"}' selected="" value="800">〜8000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長9000"}' value="900">〜9000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長10000"}' value="1000">〜10000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長11000"}' value="1100">〜11000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長12000"}' value="1200">〜12000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長13000"}' value="1300">〜13000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長14000"}' value="1400">〜14000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長15000"}' value="1500">〜15000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長16000"}' value="1600">〜16000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長17000"}' value="1700">〜17000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長18000"}' value="1800">〜18000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長19000"}' value="1900">〜19000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長20000"}' value="2000">〜20000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車長21000"}' value="2100">〜21000mm</option>
# </select>
# </div>
# </div>
# <label class="truck-condition__title" for="">車高<span class="inline-block img-icon_key"></span></label>
# <div class="truck-condition__fit-content modal-open">
# <div class="truck-condition__fit-content--disabled">
# <select disabled="" id="truck-height-dummy" name="car-height">
# <option value="-1">指定なし</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高11000"}' value="110">〜1100mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高12000"}' value="120">〜1200mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高13000"}' value="130">〜1300mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高14000"}' value="140">〜1400mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高15000"}' value="150">〜1500mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高16000"}' value="160">〜1600mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高17000"}' value="170">〜1700mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高18000"}' value="180">〜1800mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高19000"}' value="190">〜1900mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高20000"}' value="200">〜2000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高21000"}' value="210">〜2100mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高22000"}' value="220">〜2200mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高23000"}' value="230">〜2300mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高24000"}' value="240">〜2400mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高25000"}' value="250">〜2500mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高26000"}' value="260">〜2600mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高27000"}' value="270">〜2700mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高28000"}' value="280">〜2800mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高29000"}' value="290">〜2900mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高30000"}' value="300">〜3000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高31000"}' value="310">〜3100mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高32000"}' value="320">〜3200mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高33000"}' value="330">〜3300mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高34000"}' value="340">〜3400mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高35000"}' value="350">〜3500mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高36000"}' value="360">〜3600mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高37000"}' value="370">〜3700mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高38000"}' selected="" value="380">〜3800mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高39000"}' value="390">〜3900mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高40000"}' value="400">〜4000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車高41000"}' value="410">〜4100mm</option>
# </select>
# </div>
# </div>
# <label class="truck-condition__title" for="">車幅<span class="inline-block img-icon_key"></span></label>
# <div class="truck-condition__fit-content modal-open">
# <div class="truck-condition__fit-content--disabled">
# <select disabled="" id="truck-width-dummy" name="car-width">
# <option value="-1">指定なし</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅11000"}' value="110">〜1100mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅12000"}' value="120">〜1200mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅13000"}' value="130">〜1300mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅14000"}' value="140">〜1400mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅15000"}' value="150">〜1500mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅16000"}' value="160">〜1600mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅17000"}' value="170">〜1700mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅18000"}' value="180">〜1800mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅19000"}' value="190">〜1900mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅20000"}' value="200">〜2000mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅21000"}' value="210">〜2100mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅22000"}' value="220">〜2200mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅23000"}' value="230">〜2300mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅24000"}' value="240">〜2400mm</option>
# <option data-ga-click='{"action":"ルート検索_TOP", "label":"トラック条件_車幅25000"}' selected="" value="250">〜2500mm</option>
# </select>
# </div>
# </div>
# </section>
# </section>
# </div>
# </div>
# </div>
# <div class="route-search-button">
# <button class="orange-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"ルート検索ボタン"}'>ルート検索</button>
# </div>
# <div class="js-route-search-sansan" style="">
# <div style="margin-bottom: 40px;">
# <a href="/cooperation/map/?fromlink=pcnavi.map.leftPanel.banner">
# <img alt="Sansan連携" data-ga-click='{"action":"アプリ紹介バナー", "label":"Sansan連携"}' src="/static/pc/l/11.5.3/img/cooperation/lp/sansan_banner.png" width="85%"/>
# </a>
# </div></div>
# <div class="drive-route-search-box-footer-banner" style="display:none;">
# <a href="//www.navitime.co.jp/drivetool/" style="margin-bottom: 12px; display: block;" target="_blank">
# <img alt="ドライブマップツール" src="/static/pc/l/11.5.3/img/map/leftPane/drive-tool-banner.png" style="width: 301px;"/>
# </a>
# <div style="margin-bottom: 15px;">
# <a class="route-search-box__drive-banner" href="https://bit.ly/31tOzof" target="_blank">
# <img alt="超渋滞回避ルート" data-ga-click='{"action":"アプリ紹介バナー", "label":"アプリ版ならもっと便利に！超渋滞回避ルート"}' id="car_route_left_img" src="/static/pc/l/11.5.3/img/drive/banner/avoid_traffic.png" target="_blank" width="85%"/>
# </a>
# </div>
# <a href="//travel.navitime.co.jp/car?cid=pcnavi.drive.result" target="_blank">
# <img alt="NAVITIME TRAVEL" class="travel-car-reserve-banner" src="/static/pc/l/11.5.3/img/map/leftPane/travel-car-reserve-banner.svg"/>
# </a>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/116100890/PC_map_280x130', [280, 130], 'div-gpt-ad-1472712351421-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- /116100890/PC_map_280x130 -->
# <div id="div-gpt-ad-1472712351421-0" style="height:130px; width:280px;">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1472712351421-0'); });
# </script>
# </div></div>
# <div class="route-search-box-footer-banner" style="display:none;">
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//securepubads.g.doubleclick.net/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/116100890/PC_map_300x250', [300, 250], 'div-gpt-ad-1468462502830-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- /116100890/PC_map_300x250 -->
# <div id="div-gpt-ad-1468462502830-0" style="height:250px; width:300px;">
# <script type="text/javascript">
# 	googletag.cmd.push(function() { googletag.display('div-gpt-ad-1468462502830-0'); });
# </script>
# </div>
# </div>
# <div class="truck-route-search-box-footer-banner" style="display:none;">
# <div style="margin-bottom: 108px;">
# <a class="route-search-box__drive-banner" href="https://products.navitime.co.jp/service/truck/?from=pc_navitime_route_search" target="_blank">
# <img alt="トラックルート" data-ga-click='{"action":"アプリ紹介バナー", "label":"アプリ版ならもっと便利に！トラックルート"}' id="car_route_left_img" src="/static/pc/l/11.5.3/img/map/leftPane/routeSearch/banner_truck.png" target="_blank" width="85%"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="route-result-content">
# </div></div>
# <div id="poi-info-area" style="display: none">
# <div id="poi-info"></div>
# <div id="poi-ad-area"></div>
# </div>
# <div id="map-around-search" style="display: none">
# <div id="around-search-pane">
# <div class="pane-content">
# <script id="around-header-tmpl" type="text/template">
# <div class="title">
# 	{{#isSearch}}
# 		<div class="back-btn-area">
# 			<div class="cancel-back-btn img-back-btn"><img src="/static/pc/l/11.5.3/img/map/common/ic-map-back-gray.svg">周辺検索TOPに戻る</div>
# 		</div>
# 	{{/isSearch}}
# 	{{^isSearch}}
# 		<span>周辺検索</span>
# 	{{/isSearch}}
#
# 	<div class="tooltip right">
# 		<img class="close-btn" src="/static/pc/l/11.5.3/img/map/common/ic-map-close-gray.svg">
# 		<div class="description">周辺検索を閉じる</div>
# 	</div>
#
# </div>
# <div class="address">
# 	<span id="around-address">{{aroundName}}</span>&nbsp;の周辺
# </div>
# </script>
# <div id="header-content">
# </div><div id="result-header-content"></div>
# <div id="around-content"></div>
# </div>
# <script id="around-loading-tmpl" type="text/template">
# <div class="result-content">
# 	<div class="loading overflow-auto"><img alt="loading" src="/static/pc/l/11.5.3/img/common/loading.gif"></div>
# </div>
# </script>
# </div></div>
# </div>
# </div></div>
# <div id="under-advertisement">
# <div class="under-advertisement-close under-banner-close img-btn_close"></div>
# <div id="road-work-banner-area"></div>
# </div>
# <div id="map-traffic-area">
# <div class="traffic-container">
# <div class="img-jam_estimate_title"></div>
# <div class="date-container">
# <div class="title float-left">日付</div>
# <div class="prev-date-btn img-trafficgraph_btn_early float-left" data-ga-click='{"action":"渋滞パネル", "label":"前日ボタン"}'></div>
# <div class="float-left" id="traffic-date"></div>
# <div class="next-date-btn img-trafficgraph_btn_late float-left" data-ga-click='{"action":"渋滞パネル", "label":"次日ボタン"}'></div>
# <a class="float-right" data-ga-click='{"action":"渋滞パネル", "label":"カレンダー"}' id="calendarBtn">カレンダー</a>
# <div class="img-icon_calender float-right"></div>
# <input id="calendar" type="text"/>
# </div>
# <div class="time-container">
# <div class="title float-left">時刻</div>
# <div class="float-left" id="traffic-time"></div>
# <button class="white-btn float-right" data-ga-click='{"action":"渋滞パネル", "label":"現在時刻"}' id="currentBtn">現在時刻</button>
# </div>
# <div class="slider-container">
# <div id="slider"></div>
# <div class="img-jam_estimate_scale"></div>
# </div>
# <div class="info-container"></div>
# <input id="x-ntj-uid" type="hidden" value="">
# </input></div></div>
# <div id="map-rainfall-area" style="display: none;">
# <div class="rainfall-container">
# <div class="rainfall-title">降雨レーダー</div>
# <div id="current-value"></div>
# <div id="slider-area">
# <label>
# <input data-ga-change='{"action":"降雨レーダースライダー", "label":"時間変更"}' id="offset-time" list="range-list" max="60" min="-60" step="5" type="range" value="0"/>
# <datalist id="range-list">
# <option value="-60">
# <option value="-30">
# <option value="0">
# <option value="30">
# <option value="60">
# </option></option></option></option></option></datalist>
# <div class="slider-ruler">
# <ul class="slider-ruler-list">
# <li class="slider-ruler-list-item">
# <span class="slider-ruler-list-item-text">1時間前</span>
# </li>
# <li class="slider-ruler-list-item">
# <span class="slider-ruler-list-item-text">30分前</span>
# </li>
# <li class="slider-ruler-list-item">
# <span class="slider-ruler-list-item-text">現在時刻</span>
# </li>
# <li class="slider-ruler-list-item">
# <span class="slider-ruler-list-item-text">30分後</span>
# </li>
# <li class="slider-ruler-list-item">
# <span class="slider-ruler-list-item-text">1時間後</span>
# </li>
# </ul>
# </div>
# </label>
# </div>
# </div></div>
# <div id="modal"></div>
# <div id="modal-premium-regist-content"></div>
# <div id="map-footer">
# <div class="footer-action-area flex-center">
# <div class="zoom-bar flex-center">
# <a class="zoom-bar-btn flex-center" data-ga-click='{"action":"地図拡大","label":"地図拡大"}' id="zoom-in-btn">
# <div class="plus icon"></div>
# </a>
# <div class="separator"></div>
# <a class="zoom-bar-btn flex-center" data-ga-click='{"action":"地図縮小","label":"地図縮小"}' id="zoom-out-btn">
# <div class="minus icon"></div>
# </a>
# </div>
# <a class="footer-action-btn flex-center" data-ga-click='{"action":"現在地","label":"現在地"}' id="current-location-btn">
# <div class="icon-base enabled"></div>
# </a>
# <div class="footer-action-btn footer-action-btn__prefecture flex-center" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー"}' id="prefecture-list-btn">
# <div class="icon-area enabled"></div>
# <ul class="map-action-list">
# <li class="prefecture-category-label">
# <label class="prefecture-category">北海道/東北</label>
# </li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_北海道"}' data-pref-id="01">
#                 北海道</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_青森県"}' data-pref-id="02">
#                 青森県</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_岩手県"}' data-pref-id="03">
#                 岩手県</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_宮城県"}' data-pref-id="04">
#                 宮城県</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_秋田県"}' data-pref-id="05">
#                 秋田県</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_山形県"}' data-pref-id="06">
#                 山形県</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_福島県"}' data-pref-id="07">
#                 福島県</li>
# <li class="prefecture-category-label">
# <label class="prefecture-category">関東</label>
# </li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_東京都"}' data-pref-id="13">
#                 東京都</li>
# <li class="prefecture-element" data-ga-click='{"action":"フッター", "label":"ジャンプメニュー_神奈川県"}' data-pref-id="14">
#                 神奈川県</li>
# ...
# 		<div class="icon {{className}}"></div>
# 		<div class="information">
# 			<div class="time">{{time}}</div>
# 			<div class="name">{{name}}</div>
# 			<div class="road-name">{{roadName}}</div>
# 		</div>
# 	</div>
# </script>
# <script id="centerInfoWindow-tmpl" type="text/template">
# 	<div style="text-align:center;">
# 		<div>ピンをドラッグ＆ドロップして<br>中心点を変更すると<br>再検索が行なえます</div>
# 		<div id="around_description">
# 			<a>今後表示しない</a>
# 		</div>
# 	</div>
# </script>
# <script id="info-balloon-tmpl" type="text/template">
# 	<div id="balloon" class="infoWindow-tmpl">
# 		{{#type}}
# 		<div class="infoWindow-img"><span class="icon-{{type}} img-icon_spotname_{{type}}"></span></div>
# 		{{/type}}
# 		<div>
# 			<div class="infoWindow-title">{{name}}</div>
# 			<div class="infoWindow-info address"><p class="infoWindow-content">{{address}}</p></div>
# 		</div>
# 		<div class="clear"></div>
# 		<div class="infoWindow-info">
# 			<span class="icon-info img-icon_info"></span>
# 			<ul class="infoWindow-link-list">
# 				<li class="infoWindow-first">
# 					<a class="infoWindow-link" href="//www.navitime.co.jp{{detailLink}}" target="_blank"
# 					   data-ga-click='{"action":"吹き出し", "label":"詳細情報"}'>詳細情報</a>
# 					<div class="infoWindow-around"><a class="infoWindow-around-search-button"
# 					                                  data-request="{{aroundLink}}"
# 					                                  data-ga-click='{"action":"吹き出し", "label":"この地点の周辺情報"}'>この地点の周辺情報</a>
# 					</div>
# 				</li>
# 			</ul>
# 		</div>
# 		<input type="hidden" name="data" value="{{poi}}">
# 	</div>
# </script>
# <script id="routeSearch-via-box-tmpl" type="text/template">
# <div class="route-search-via-box search-box-content" data-box="via">
# 	<div class="search-box route-search-box">
# 		<label class="via">経由</label>
# 		<input class="via-input" type="text" placeholder="経由地を入力"/>
# 		<input type="hidden" value="">
# 		<button class="search-btn orange-btn" data-ga-click='{"action":"ルート検索_TOP", "label":"地点検索ボタン"}'>
# 			<div class="img-icon_btn_search"></div>
# 		</button>
# 		<div class="delete-btn img-btn_cancel_normal" data-ga-click='{"action":"ルート検索_TOP", "label":"経由削除ボタン"}'></div>
# 		<div class="sort-btn img-icon_via_sort"></div>
# 		<select id="stay_time_select" name="stay_time" data-ga-click='{"action":"ルート検索_TOP", "label":"経由_滞在時間"}'>
# 			<option value="0" data-ga-click='{"action":"ルート検索_TOP", "label":"0分滞在"}'>0分滞在</option>
# 			<option value="30" data-ga-click='{"action":"ルート検索_TOP", "label":"30分滞在"}'>30分滞在</option>
# 			<option value="60" data-ga-click='{"action":"ルート検索_TOP", "label":"60分滞在"}'>60分滞在</option>
# 			<option value="90" data-ga-click='{"action":"ルート検索_TOP", "label":"90分滞在"}'>90分滞在</option>
# 			<option value="120" data-ga-click='{"action":"ルート検索_TOP", "label":"120分滞在"}'>120分滞在</option>
# 			<option value="180" data-ga-click='{"action":"ルート検索_TOP", "label":"180分滞在"}'>180分滞在</option>
# 		</select>
# 	</div>
# 	<div class="search-result"></div>
# 	<div class="suggest-result"></div>
# </div>
# </script>
# <script id="area-target-tmpl" type="text/template">
# <a href="javascript:void(0);" id="car-target"
# 	data-ad-click='{"url": "{{url}}", "target": "_blank", "key": "{{clickParam}}"}' data-ad-imp='{"key": "{{impParam}}"}'>
# 	<img src="/pcstorage/img/upTool/{{imgUrl}}">
# </a>
# </script>
# <script id="cross-match-tmpl" type="text/template">
# <iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0" vspace="0" hspace="0" bordercolor="#000000" src="{{src}}" class="{{className}}">
# </iframe>
# </script>
# <script id="map-pane-ad-tmpl" type="text/template">
# 	<iframe frameborder="0" scrolling="no" marginheight="0" marginwidth="0" vspace="0" hspace="0" bordercolor="#000000" src="{{src}}" class="{{className}}">
# 	</iframe>
# </script>
# <div class="str-define" id="menuStr">
# <input class="menuStr-goFrom" type="hidden" value="出発地に設定する"/>
# <input class="menuStr-goto" type="hidden" value="目的地に設定する"/>
# <input class="menuStr-setVia" type="hidden" value="経由地に設定する"/>
# <input class="menuStr-aroundSearch" type="hidden" value="ここを中心に周辺検索する"/>
# <input class="menuStr-setCenter" type="hidden" value="この場所の情報を表示する"/>
# <input class="menuStr-mapUrl" type="hidden" value="この場所のURLを表示する"/>
# <input class="menuStr-mailTo" type="hidden" value="メールを送信する"/>
# </div>
# <input id="map-type" type="hidden" value=""/>
# <script>
#         // フリーパスリストを格納
#         FREEPASS_LIST = []
# 	</script>
# <script>
#             FREEPASS_LIST.push({no:"0", name:"指定なし", mochaParam: ""})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"1", name:"青春18きっぷ", mochaParam: "youth18_pass_basic.youth18_pass_express.youth18_pass_3rdsec"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"2", name:"大阪周遊パス1日券(大阪エリア版)", mochaParam: "osaka_pass"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"3", name:"大阪周遊パス1日券（阪急拡大版)", mochaParam: "osaka_pass.osaka_pass_hankyu"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"4", name:"大阪周遊パス1日券(阪神拡大版)", mochaParam: "osaka_pass.osaka_pass_hanshin"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"5", name:"大阪周遊パス1日券(南海関空版)", mochaParam: "osaka_pass.osaka_pass_nankai"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"6", name:"大阪周遊パス1日券(万博記念公園版)", mochaParam: "osaka_pass.osaka_pass_banpaku"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"7", name:"大阪周遊パス2日券", mochaParam: "osaka_pass_2day"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"8", name:"ようこそ大阪きっぷ（乗り降り自由区間のみ対応）", mochaParam: "yokoso_osaka"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"9", name:"高野山・世界遺産きっぷ（乗り降り自由区間のみ対応）", mochaParam: "koyasan_world_heritage"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"10", name:"江の島・鎌倉フリーパス（乗り降り自由区間のみ対応）", mochaParam: "enoshima_kamakura"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"11", name:"箱根フリーパス（乗り降り自由区間のみ対応）", mochaParam: "hakone"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"12", name:"カンサイスルーパス 2dayチケット", mochaParam: "kansai_thru_two_day_and_three_day_ticket"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"13", name:"東京メトロ24時間券", mochaParam: "tokyo_metro_24hour"})
# 		</script>
# <script>
#             FREEPASS_LIST.push({no:"14", name:"東京フリーきっぷ", mochaParam: "tokyo_one_day_ticket"})
# 		</script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery-1.11.1.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.loading.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.adcount.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.gacount.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.ah-placeholder.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.inview.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/hogan-3.0.2.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/json2.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/underscore-1.7.0.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/backbone-1.1.2.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/moment.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.qrcode.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/common/nt_common.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery-ui.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/datepicker-ja.js"></script>
# <!-- nt-common.jsp is essential -->
# <script>
# 	(function () {
# 		var namespace = navitime.namespace("navitime.common.resource");
#
# 		var Path = {
# 			PcnaviTop: "//www.navitime.co.jp",
# 			Storage: "/static/pc/l/11.5.3/",
# 			Image: "/static/pc/l/11.5.3/img/",
# 			PcnaviImage: "https://www.navitime.co.jp/pcstorage/img/",
#             Storm: "//static.media.cld.navitime.jp"
# 		};
#
# 		namespace.Path = Path;
#
# 	})();
# </script>
# <script src="/static/pc/l/11.5.3/js/common/nt_net.js"></script>
# <script src="/static/pc/l/11.5.3/js/common/nt_location.js"></script>
# <script src="/static/pc/l/11.5.3/js/common/nt_mocha.js"></script>
# <script src="/static/pc/l/11.5.3/js/common/nt_map_v2.js"></script>
# <script src="/static/pc/l/11.5.3/js/common/nt_definition.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/Chart.min.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/jquery.cookie.min.js"></script>
# <script type="text/javascript">
# 	    !function(a,b,c,d){if(!b[a]){b[a]=function(){b[a].instances.push(this),this.init&&this.init()},b[a].instances=[];for(var e=0,f=["td_send","td_send_imid"];e<f.length;e++)b[a].prototype[f[e]]=function(a){return function(){this["tmp_"+a]=this["tmp_"+a]||[],this["tmp_"+a].push(Array.prototype.slice.call(arguments))}}(f[e]);var g=c.getElementsByTagName(d)[0],h=c.createElement(d);h.async=!0,h.src="//cf.im-apps.net/sdk/tdim-1.1.0.min.js",g.parentNode.insertBefore(h,g)}}("TDIM",window,document,"script");
# 	</script>
# <script type="text/javascript">
#
# function getCookieByRegexp(pattern) {
# 	var _cookies = document.cookie;
# 	var match = pattern.exec(_cookies);
# 	if(match){
# 		return match[1];
# 	}
# 	return "";
# };
# </script>
# <script src="/static/pc/l/11.5.3/js/view/map/ajax.js"></script>
# <script src="/static/pc/l/11.5.3/js/view/map/action.js"></script>
# <script src="/static/pc/l/11.5.3/js/view/map/model.js"></script>
# <script src="/static/pc/l/11.5.3/js/view/map/ctl.js"></script>
# <script src="/static/pc/l/11.5.3/js/lib/NTWindow.jquery.js"></script>
# <div id="modal-content">
# <div id="login-modal">
# <div class="modal-view-header" id="login-modal-header">
# <div class="left">NAVITIME IDでログイン</div>
# <div class="right"><a class="button-link modal-close-btn" id="modal-close">×</a></div>
# <div class="clear"></div>
# </div>
# <div id="login-modal-content">
# <div id="login-modal-login-content">
# <form action="//www.navitime.co.jp" class="form form-inline" method="POST" name="login" onsubmit="if(document.login.user.value=='' || document.login.passwd.value==''){ alert('ID、パスワードを入力してください。'); return false;}">
# <input class="login-modal-input font-18" id="login_user" name="user" onkeypress='if((event.keyCode == 13 || event.charCode == 13)) {document.getElementById("login_url").value = location.href;document.forms["login"].submit();}' placeholder="NAVITIMEID" title="NAVITIMEID" type="text"/>
# <input class="login-modal-input font-18" id="login_passwd" name="passwd" onkeypress='if((event.keyCode == 13 || event.charCode == 13)) {document.getElementById("login_url").value = location.href;document.forms["login"].submit();}' placeholder="パスワード" title="パスワード" type="password"/>
# <input id="login_url" name="url" type="hidden" value=""/>
# <br/>
# <label class="checkbox">
# <input class="box" id="autologin" name="autologin" type="checkbox" value="1"/>次回から自動的にログイン</label><br/>
# <div class="button blue-btn" id="login-btn" onclick='document.getElementById("login_url").value = location.href;document.forms["login"].submit();'>ログイン</div>
# <input name="invite" type="hidden" value="limemap"/>
# </form>
# <div class="line"></div>
# <div id="forget-pass">
# <a href="//www.navitime.co.jp/systemnavitimeid/confirm">&gt;ID/パスワードをお忘れの方</a><br/>
# </div>
# <div class="line"></div>
# <div id="other-site-login">
# <div id="other-site-login-title">
# 								他サイトのIDでログイン</div>
# <div id="other-site-login-link">
# <ul>
# <li><a href="https://pcc.navitime.co.jp/navitimeid/prov/login/rc/start/">楽天会員の方はこちら</a></li>
# <li><a href="https://pcc.navitime.co.jp/navitimeid/prov/login/yw/start/">Yahoo！ウォレットの方はこちら</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div id="login-modal-action">
# <ul>
# <li class="line"></li>
# <li>NAVITIME IDをお持ちでない方</li>
# <li class="button"><a href="https://pcc.navitime.co.jp/navitimeid/pcc/mobilelist/?invite=limemap" style="color: #FFFFFF;">NAVITIME IDを取得</a></li>
# </ul>
# </div>
# </div>
# </div>
# <script>
# 	$(function(){
#
# 		//モーダルウィンドウを出現させるクリックイベント
# 		$("body").on("click", "#modal-open, .modal-open", function(){
# 			showLoginPopup();
# 		});
#
# 		//リサイズされたら、センタリングをする関数[centeringModalSyncer()]を実行する
# 		$(window).resize(centeringModalSyncer);
#
# 		// ログイン後に戻ってくる画面のＵＲＬ。自画面のＵＲＬをvalueに設定する
# 		$("#login_url").val(location.href);
#
# 	});
#
# 	function showLoginPopup() {
# 		//オーバーレイを出現させる
# 		$("#modal-overlay").show();
# 		$("#modal-overlay").css("height",$(document).height());
# 		$("#modal-overlay").fadeIn("slow");
#
# 		//コンテンツをセンタリングする
# 		centeringModalSyncer();
#
# 		//コンテンツをフェードインする
# 		$("#modal-content").fadeIn("slow");
#
# 		$("#modal-overlay,#modal-close").unbind().click(function(){
# 			$("#modal-content,#modal-overlay").fadeOut("slow",function(){
# 				$('#modal-overlay').hide();
# 			});
# 		});
# 	}
#
# 	//センタリングを実行する関数
# 	function centeringModalSyncer(){
#
# 		//画面(ウィンドウ)の高さを取得
# 		var w = $(window).width();
#
# 		//コンテンツ(#modal-content)の高さを取得
# 		var cw = $("#modal-content").width();
#
# 		//センタリングを実行する
# 		var pxleft = ((w - cw)/2);
# 		$("#modal-content").css({"left": pxleft + "px"});
# 	}
# 	</script>
# <div id="modal-overlay"></div>
# <input data-client="-1" data-dateinfo="2020112810_5__none" data-memberinfo="none" data-ntidhash="" data-startdate="20201128_00000000_00000000" id="ga-params" type="hidden">
# <script type="text/javascript">
# 	var gaParams = $('#ga-params').data();
# 	var _gaq = _gaq || [];
# 	var pluginUrl = '//www.google-analytics.com/plugins/ga/inpage_linkid.js';
# 	_gaq.push(['_require', 'inpage_linkid', pluginUrl]);
# 	_gaq.push(['_setAccount', 'UA-27448126-2']);
# 	_gaq.push(['_setCustomVar', 1, 'clnt', gaParams.client, 3]);
# 	_gaq.push(['_setCustomVar', 2, 'info', gaParams.memberInfo, 3]);
# 	_gaq.push(['_setCustomVar', 4, 'dateInfo', gaParams.dateinfo, 2]);
# 	_gaq.push(['_setCustomVar', 5, 'startDate', gaParams.startDate, 1]);
# 	_gaq.push(['_trackPageview']);
# 	(function() {
# 		var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 		ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
# 		var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 	})();
#
# 	if (document.referrer.match(/google\.(com|co\.jp)/gi) && document.referrer.match(/cd/gi)) {
# 		var ga_myString = document.referrer;
# 		var ga_r        = ga_myString.match(/cd=(.*?)&/);
# 		var ga_rank     = parseInt(ga_r[1]);
# 		var ga_kw       = ga_myString.match(/q=(.*?)&/);
#
# 		if (ga_kw[1].length > 0) {
# 			var ga_keyWord  = decodeURI(ga_kw[1]);
# 		} else {
# 			ga_keyWord = "(not provided)";
# 		}
#
# 		var ga_p        = document.location.pathname;
# 		_gaq.push(['_trackEvent', 'RankTracker', ga_keyWord, ga_p, ga_rank, true]);
# 	}
#
#
# 	var gaUaClientId = gaParams.ntidHash;
# 	if (gaUaClientId != ""){
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 				m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 				})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 			ga('create', 'UA-39959835-1', {'cookieDomain': 'navitime.co.jp', 'clientId': gaUaClientId});
# 			ga('send', 'pageview');
# 	}
# 	</script>
# <script type="text/javascript">
# 	try{jQuery('a[href^="mailto:"]').live('click',function(){_gaq.push(['_trackEvent','Email','mailto',this.href]);});}catch(e){}
# 	</script>
# <img height="1" src="//tg.socdm.com/aux/extsync?aid=navitime&amp;sid=test_PC&amp;attr_raw=all%3d1" style="display:none;position:absolute;border:none;padding:0;margin:0;" width="1"><img src="//www.navitime.co.jp/pcstorage/cntlog/20201128102516?ctl=map.map&amp;path-group=map" style="display:none;"/><script type="text/javascript">
# window.dataLayer = window.dataLayer || [];
# dataLayer.push({
# 	'出発路線': '',
# 	'到着路線': '',
# 	'出発地点': '',
# 	'到着地点': '',
# 	'日付時刻': '',
# 	'検索種別': '',
# 	'経由地点': '',
# 	'表示順序': '',
# 	'徒歩速度': '',
# 	'使用交通': '',
# 	'路線': ''
# });
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TGJN5X" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TGJN5X');</script>
# <!-- End Google Tag Manager --></img></input></body>
# </html>

# %%
# find button to turn off cars as an option
car_button = soup.find("div", class_="route-search-details-link")

# %%
# click botton to turn off cars as an option to search - need to figure out way to click this button.... 
# or filter out car info 
#br.submit("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-0ac6d3bebc89> in <module>
#       1 # click botton to turn off cars as an option to search
# ----> 2 br.submit("ルート検索")
#
# /usr/local/lib/python3.9/site-packages/mechanize/_mechanize.py in submit(self, *args, **kwds)
#     695         Return value is same as for :meth:`open()`.
#     696         """
# --> 697         return self.open(self.click(*args, **kwds))
#     698
#     699     def click_link(self, link=None, **kwds):
#
# /usr/local/lib/python3.9/site-packages/mechanize/_mechanize.py in click(self, *args, **kwds)
#     685         if not self.viewing_html():
#     686             raise BrowserStateError("not viewing HTML")
# --> 687         request = self.form.click(*args, **kwds)
#     688         return self._add_referer_header(request)
#     689
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %%
# find input location and input something there 
br.
